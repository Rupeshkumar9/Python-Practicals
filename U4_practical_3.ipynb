# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np


# Load dataset (64 features)
digits = load_digits()
X = digits.data
y = digits.target
print(f"Original shape: {X.shape}")


# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2) # reduce to 2 dimensions
X_pca = pca.fit_transform(X_scaled)
print(f"Reduced shape: {X_pca.shape}")
print(f"Explained variance Ratio: {pca.explained_variance_ratio_}")
print(f"Total variance explained: {sum(pca.explained_variance_ratio_):.4f}")

# Visualize 2D projecƟon
plt.figure(figsize=(10, 8))
scaƩer = plt.scatter(X_pca[:, 0], X_pca[:, 1],
c=y, cmap='tab10', alpha=0.6, edgecolors='k')
plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%} variance)')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%} variance)')
plt.title('PCA: Digits Dataset (64D → 2D)')
plt.colorbar(scaƩer, label='Digit Class')
plt.show()
# Out:
# Original shape: (1797, 64)
# Reduced shape: (1797, 2)
# Explained variance Ratio: [0.12033916 0.09561054]
# Total variance explained: 0.2159
